# %% [markdown]
# PART 1:

# %% [markdown]
# Q1_1:

# %%
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt

X, y = make_classification(
    n_samples=1000,
    n_features=2,
    n_informative=2,
    n_redundant=0,
    n_clusters_per_class=1,
    n_classes=2,
    class_sep=1.8,
    random_state=23
)

plt.scatter(X[:, 0], X[:, 1], c=y)
plt.xlabel('data set 1')
plt.ylabel('data set 2')
plt.title('Generated Dataset')
plt.colorbar(label='Class')
plt.show()

# %% [markdown]
# Q1_2:

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, Perceptron, SGDClassifier

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

models = [
    LogisticRegression(random_state=23),
    Perceptron(random_state=23, penalty='l2'),
    SGDClassifier(random_state=23, loss='hinge')
]

def train_and_evaluate(model, X_train, X_test, y_train, y_test):
    model_name = type(model).__name__
    model.fit(X_train, y_train)
    model.predict(X_test)
    train_score = model.score(X_train, y_train)
    test_score = model.score(X_test, y_test)
    print(f"{model_name} train score is: {train_score}")
    print(f"{model_name} test score is: {test_score}\n")

for model in models:
    train_and_evaluate(model, X_train, X_test, y_train, y_test)
# Out:
# LogisticRegression train score is: 0.96625
# LogisticRegression test score is: 0.935
#
# Perceptron train score is: 0.92875
# Perceptron test score is: 0.92
#
# SGDClassifier train score is: 0.9675
# SGDClassifier test score is: 0.94

# %% [markdown]
# Q1_3:

# %%
colors = np.array(['green', 'black'])
plt.scatter(X[:, 0], X[:, 1], c=colors[y])
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, Perceptron, SGDClassifier

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

models = [
    LogisticRegression(random_state=23),
    Perceptron(random_state=23, penalty='l2'),
    SGDClassifier(random_state=23, loss='hinge')
]

def train_and_evaluate(model, X_train, X_test, y_train, y_test):
    model_name = type(model).__name__
    model.fit(X_train, y_train)
    model.predict(X_test)
    train_score = model.score(X_train, y_train)
    test_score = model.score(X_test, y_test)
    print(f"{model_name} train score is: {train_score}")
    print(f"{model_name} test score is: {test_score}\n")

for model in models:
    train_and_evaluate(model, X_train, X_test, y_train, y_test)
# Out:
# LogisticRegression train score is: 0.95875
# LogisticRegression test score is: 0.965
#
# Perceptron train score is: 0.9625
# Perceptron test score is: 0.965
#
# SGDClassifier train score is: 0.9375
# SGDClassifier test score is: 0.94

# %%
from sklearn.linear_model import LogisticRegression
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt
import numpy as np


model1_3 = LogisticRegression()
model1_3.fit(X, y)

y_pred = model1_3.predict(X)
misclassified = np.where(y != y_pred)

plot_decision_regions(X, y, clf=model1_3, legend=2)
misclassified_points = X[misclassified]

ax = plt.gca()
ax.scatter(misclassified_points[:, 0], misclassified_points[:, 1],
facecolors='none', edgecolors='r', marker='o', label='Misclassified')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.legend()
plt.show()

# %% [markdown]
# Q1_4:

# %%
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt

X, y = make_classification(
    n_samples=1000,
    n_features=2,
    n_informative=2,
    n_redundant=0,
    n_clusters_per_class=2,
    n_classes=2,
    class_sep=0.8,
    random_state=23
)

plt.scatter(X[:, 0], X[:, 1], c=y)
plt.xlabel('data set 1')
plt.ylabel('data set 2')
plt.title('Generated Dataset')
plt.colorbar(label='Class')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, Perceptron, SGDClassifier

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

models = [
    LogisticRegression(random_state=23),
    Perceptron(random_state=23, penalty='l2'),
    SGDClassifier(random_state=23, loss='hinge')
]

def train_and_evaluate(model, X_train, X_test, y_train, y_test):
    model_name = type(model).__name__
    model.fit(X_train, y_train)
    model.predict(X_test)
    train_score = model.score(X_train, y_train)
    test_score = model.score(X_test, y_test)
    print(f"{model_name} train score is: {train_score}")
    print(f"{model_name} test score is: {test_score}\n")

for model in models:
    train_and_evaluate(model, X_train, X_test, y_train, y_test)
# Out:
# LogisticRegression train score is: 0.86125
# LogisticRegression test score is: 0.875
#
# Perceptron train score is: 0.83125
# Perceptron test score is: 0.79
#
# SGDClassifier train score is: 0.8575
# SGDClassifier test score is: 0.85

# %%
from sklearn.linear_model import LogisticRegression
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt
import numpy as np


model1_3 = LogisticRegression()
model1_3.fit(X, y)

y_pred = model1_3.predict(X)
misclassified = np.where(y != y_pred)

plot_decision_regions(X, y, clf=model1_3, legend=2)
misclassified_points = X[misclassified]

ax = plt.gca()
ax.scatter(misclassified_points[:, 0], misclassified_points[:, 1],
facecolors='none', edgecolors='r', marker='o', label='Misclassified')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.legend()
plt.show()

# %% [markdown]
# Q1_5:

# %%
X, y = make_classification(
    n_samples=1000,
    n_features=2,
    n_informative=2,
    n_redundant=0,
    n_clusters_per_class=1,
    n_classes=3,
    class_sep=1.8,
    random_state=23
)

plt.scatter(X[:, 0], X[:, 1], c=y)
plt.xlabel('data set 1')
plt.ylabel('data set 2')
plt.title('Generated Dataset')
plt.colorbar(label='Class')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_decision_regions
from sklearn.linear_model import LogisticRegression, Perceptron, SGDClassifier

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

models = [
    LogisticRegression(random_state=23),
    Perceptron(random_state=23, penalty='l2'),
    SGDClassifier(random_state=23, loss='hinge')
]

def train_and_evaluate(model, X_train, X_test, y_train, y_test):
    model_name = type(model).__name__
    model.fit(X_train, y_train)
    model.predict(X_test)
    train_score = model.score(X_train, y_train)
    test_score = model.score(X_test, y_test)
    print(f"{model_name} train score is: {train_score}")
    print(f"{model_name} test score is: {test_score}\n")

for model in models:
    train_and_evaluate(model, X_train, X_test, y_train, y_test)
# Out:
# LogisticRegression train score is: 0.97
# LogisticRegression test score is: 0.975
#
# Perceptron train score is: 0.955
# Perceptron test score is: 0.945
#
# SGDClassifier train score is: 0.9725
# SGDClassifier test score is: 0.975

# %%
from sklearn.linear_model import LogisticRegression
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt
import numpy as np


model1_3 = LogisticRegression()
model1_3.fit(X, y)

y_pred = model1_3.predict(X)
misclassified = np.where(y != y_pred)

plot_decision_regions(X, y, clf=model1_3, legend=2)
misclassified_points = X[misclassified]

ax = plt.gca()
ax.scatter(misclassified_points[:, 0], misclassified_points[:, 1],
facecolors='none', edgecolors='r', marker='o', label='Misclassified')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.legend()
plt.show()

# %% [markdown]
# PART 2:

# %% [markdown]
# Q2_1:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gdown
url = 'https://drive.google.com/file/d/1loB4ihlR6Oej-6TRNyyBy8A94DmvRSG7'
output = 'data_banknote_authentication.txt'
gdown.download(url, output, quiet=False)

df = pd.read_csv("data_banknote_authentication.txt")
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/parse_url.py:35: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=None
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/file/d/1loB4ihlR6Oej-6TRNyyBy8A94DmvRSG7
# To: /content/data_banknote_authentication.txt
# 6.86kB [00:00, 8.91MB/s]

# %% [markdown]
# Q2_2

# %%
from sklearn.model_selection import train_test_split

df_shuffled = df.sample(frac=1, random_state=23).reset_index(drop=True)

X = df_shuffled.iloc[:, :-1].values
y = df_shuffled.iloc[:, -1].values.reshape(-1, 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %% [markdown]
# Q2_3

# %%
df = pd.read_csv('/content/banknote authentication.csv')
df

mdf = df.sample(frac = 1,random_state=13)
mdf


X = mdf[['f1','f2','f3','f4']].values
y = mdf[['target']].values
X,y


X_train , X_test , y_train , y_test = train_test_split(X,y,test_size=0.2 , random_state=13)
X_train.shape , X_test.shape ,y_train.shape, y_test.shape

import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def logistic_regression(x, w):
    y_hat = sigmoid(x @ w)
    return y_hat

def bce(y, y_hat):
    loss = -(np.mean(y * np.log(y_hat) + (1 - y) * np.log(1 - y_hat)))
    return loss

def gradient(x, y, y_hat):
    grads = (x.T @ (y_hat - y)) / len(y)
    return grads

def gradient_descent(w, eta, grads):
    w -= eta * grads
    return w

def accuracy(y, y_hat):
    acc = np.sum(y == np.round(y_hat)) / len(y)
    return acc


X_train = np.hstack((np.ones((len(X_train), 1)), X_train))

m = X_train.shape[1] - 1
w = np.random.randn(m + 1, 1)
eta = 0.01
n_epoch = 1000

error_hist = []
for epoch in range(n_epoch):
    y_hat = logistic_regression(X_train, w)
    e = bce(y_train, y_hat)
    error_hist.append(e)
    grads = gradient(X_train, y_train, y_hat)
    w = gradient_descent(w, eta, grads)
    if (epoch + 1) % 100 == 0:
        print(f'Epoch={epoch}, \t E={e:.4f}, \t w={w.T[0]}')

plt.plot(error_hist)
plt.title("BCE Loss over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

X_test = np.hstack((np.ones((len(X_test),1)),X_test))

y_hat2 = predict(X_test, w)
acc = accuracy(y_test, y_hat2)
print("accuracy:" + str(acc))
# Out:
# <ipython-input-76-afbbda0f1d6c>:27: RuntimeWarning: divide by zero encountered in log
#   loss = -(np.mean(y * np.log(y_hat) + (1 - y) * np.log(1 - y_hat)))
# <ipython-input-76-afbbda0f1d6c>:27: RuntimeWarning: invalid value encountered in multiply
#   loss = -(np.mean(y * np.log(y_hat) + (1 - y) * np.log(1 - y_hat)))
# Epoch=99, 	 E=0.6200, 	 w=[-0.14129273 -2.07318044 -1.61116772 -0.47453916  0.00860498]
# Epoch=199, 	 E=0.1985, 	 w=[-0.04372837 -2.11398464 -1.2020921  -0.86502479 -0.22187758]
# Epoch=299, 	 E=0.1209, 	 w=[ 0.02603339 -2.09322059 -1.04285478 -1.04739644 -0.31289611]
# Epoch=399, 	 E=0.1080, 	 w=[ 0.087692   -2.08311529 -0.99722634 -1.11268024 -0.34938345]
# Epoch=499, 	 E=0.1036, 	 w=[ 0.14697534 -2.08000021 -0.99583383 -1.13221578 -0.36924803]
# Epoch=599, 	 E=0.1000, 	 w=[ 0.20387939 -2.0779907  -1.00412723 -1.14243884 -0.38330965]
# Epoch=699, 	 E=0.0967, 	 w=[ 0.25847823 -2.07582152 -1.01412001 -1.15143275 -0.39411377]
# ...

# %% [markdown]
# Q2_4

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaled_data = scaler.fit_transform(X_train)

print("Scaled Data:")
print(scaled_data)

print("\nOriginal X_train:")
print(X_train)
# Out:
# Scaled Data:
# [[0.         0.74362691 0.35354683 0.39016065 0.77081071]
#  [0.         0.64340264 0.61150177 0.33805175 0.83387773]
#  [0.         0.44826818 0.63007183 0.17328509 0.66182997]
#  ...
#  [0.         0.66857769 0.88269887 0.09368529 0.54488036]
#  [0.         0.71864656 0.74690341 0.22449681 0.74386848]
#  [0.         0.59536739 0.85112144 0.13488676 0.72937054]]
#
# Original X_train:
# [[ 1.       3.2697  -4.3414   3.6884  -0.29829]
#  [ 1.       1.8799   2.4707   2.4931   0.37671]
#  [ 1.      -0.82601  2.9611  -1.2864  -1.4647 ]
#  ...
#  [ 1.       2.229    9.6325  -3.1123  -2.7164 ]
#  [ 1.       2.9233   6.0464  -0.11168 -0.58665]
#  [ 1.       1.2138   8.7986  -2.1672  -0.74182]]

# %% [markdown]
# Q2_5

# %%
w = np.random.randn(4, 1)
error_hist = []
error_hist_test = []

for i in range(epock):
    # Calculate predictions and errors for training set
    y_hat_train = predict(X_train, w)
    e_train = BCE(y_train, y_hat_train)
    error_hist.append(e_train)
    gradient_value = gradient(X_train, y_train, y_hat_train)
    w = gradient_descent(w, eta, gradient_value)

    y_hat_test = predict(X_test, w)
    e_test = BCE(y_test, y_hat_test)
    error_hist_test.append(e_test)

plt.plot(error_hist, label="Train Dataset", color='g')
plt.plot(error_hist_test, label="Test Dataset", color='black')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.title('Error vs. Epochs')
plt.show()
